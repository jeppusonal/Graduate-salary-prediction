# %% [markdown]
# # **Experiment Notebook**

# %% [markdown]
# <hr>

# %% [markdown]
# ## A. Project

# %%
student_name = '<fill_this>'

# %%
student_id = '<fill_this>'

# %%
experiment_id = '1'

# %% [markdown]
# <hr>

# %% [markdown]
# ## B. Experiment Description

# %%
experiment_hypothesis = '<fill_this>'

# %%
experiment_expectations = '<fill_this>'

# %% [markdown]
# <hr>

# %% [markdown]
# ## C. Data Understanding

# %% [markdown]
# ### C.0 Import Packages

# %%
# Pandas for data handling
import pandas as pd

# Scikit Learn for ML training
import sklearn

# Altair for plotting
import altair as alt

# <fill_this>
#import

# %% [markdown]
# <hr>

# %% [markdown]
# ### C.1   Load Datasets

# %%
# Load training set
# Do not change this code

X_train = pd.read_csv('X_train.csv')
y_train = pd.read_csv('y_train.csv')

# %%
# Load validation set
# Do not change this code

X_val = pd.read_csv('X_val.csv')
y_val = pd.read_csv('y_val.csv')

# %%
# Load testing set
# Do not change this code

X_test = pd.read_csv('X_test.csv')
y_test = pd.read_csv('y_test.csv')

# %% [markdown]
# <hr>

# %% [markdown]
# <hr>

# %% [markdown]
# ## D. Feature Selection

# %%
feature_selection_executive_summary = 'Use the same list of features from experiment 0.'

# %%
# <fill_this>

features_list = []

# %% [markdown]
# <hr>

# %% [markdown]
# ## E. Train Machine Learning Model

# %%
train_model_executive_summary = '<fill_this>'

# %% [markdown]
# ### E.1 Import Algorithm

# %% [markdown]
# > Rationale: <fill_this>

# %%
# <fill_this>

# %% [markdown]
# <hr>

# %% [markdown]
# ### E.2 Set Hyperparameters

# %% [markdown]
# > Rationale: <fill_this>

# %%
# <fill_this>

# %% [markdown]
# <hr>

# %% [markdown]
# ### E.3 Fit Model

# %%
# <fill_this>

# %% [markdown]
# <hr>

# %% [markdown]
# ### E.4 Model Technical Performance

# %%
# <fill_this>

# %% [markdown]
# > Results: <fill_this>

# %% [markdown]
# <hr>

# %% [markdown]
# ### E.5 Business Impact from Current Model Performance

# %%
# <fill_this>

# %% [markdown]
# > Results: <fill_this>

# %% [markdown]
# <hr>

# %% [markdown]
# ## F. Experiment Outcomes

# %%
final_experiment_outcome = 'Hypothesis Confirmed'

# %% [markdown]
# > Key Learnings: <fill_this>

# %% [markdown]
# > Recommendations for Next Experiment: <fill_this>

# %% [markdown]
# <hr>

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=737d9b25-9447-484d-8bc7-c0ef42078df9' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
