# %% [markdown]
# # **Experiment Notebook**

# %% [markdown]
# <hr>

# %% [markdown]
# ## A. Project

# %%
student_name = 'Sonal Rao'

# %%
student_id = '25533441'

# %%
experiment_id = '0'

# %%
business_objective = '<fill_this>'

# %% [markdown]
# <hr>

# %% [markdown]
# ## B. Experiment Description

# %%
experiment_hypothesis = 'There is no hypothesis to test. This is used for data exploration and analysis and required data preparation for the upcoming experiments.'

# %%
experiment_expectations = 'The goal is to assess the baseline performance for this project and fix critical data quality issues impacting models.'

# %% [markdown]
# <hr>

# %% [markdown]
# ## C. Data Understanding

# %%
data_understanding_executive_summary = '<fill_this>'

# %% [markdown]
# ### C.0 Import Packages

# %%
# Pandas for data handling
import pandas as pd

# Scikit Learn for ML training
import sklearn

# Altair for plotting
import altair as alt

# <fill_this>
import numpy as np

# %% [markdown]
# <hr>

# %% [markdown]
# ### C.1   Load Datasets

# %%
# Load training data
# Do not change this code

training_df = pd.read_csv("salary_training.csv")

# %%
# Load validation data
# Do not change this code

validation_df = pd.read_csv("salary_validation.csv")

# %%
# Load testing data
# Do not change this code

testing_df = pd.read_csv("salary_testing.csv")

# %% [markdown]
# <hr>

# %% [markdown]
# ### C.2 Explore Datasets

# %%
# <fill_this>

training_df.head()
# Out:
#         ID Gender         DOB  10percentage  12graduation  12percentage  \
# 0   301647      m  1989-08-21         77.33          2007         85.17
# 1   339001      f  1990-10-30         82.00          2008         75.00
# 2  1183070      m  1992-11-25         76.80          2010         87.70
# 3   794062      f  1993-03-15         57.00          2009         73.00
# 4  1088206      m  1990-06-21         77.00          2008         75.00
#
#    CollegeID  CollegeTier       Degree                    Specialization  ...  \
# 0       9084            2  B.Tech/B.E.  electronics & telecommunications  ...
# 1       4889            2  B.Tech/B.E.                     biotechnology  ...
# 2       5338            2  B.Tech/B.E.            information technology  ...
# 3       8346            2  B.Tech/B.E.    computer science & engineering  ...
# 4      13424            2  B.Tech/B.E.  electronics & telecommunications  ...
#
#                 city  postcode  state_abbr  \
# ...

# %%
training_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1803 entries, 0 to 1802
# Data columns (total 58 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     1803 non-null   int64
#  1   Gender                 1803 non-null   object
#  2   DOB                    1803 non-null   object
#  3   10percentage           1803 non-null   float64
#  4   12graduation           1803 non-null   int64
#  5   12percentage           1803 non-null   float64
#  6   CollegeID              1803 non-null   int64
#  7   CollegeTier            1803 non-null   int64
#  8   Degree                 1803 non-null   object
#  9   Specialization         1803 non-null   object
#  10  collegeGPA             1803 non-null   float64
#  11  CollegeCityID          1803 non-null   int64
#  12  CollegeCityTier        1803 non-null   int64
#  13  GraduationYear         1803 non-null   int64
# ...

# %%
training_df.describe()
# Out:
#                  ID  10percentage  12graduation  12percentage     CollegeID  \
# count  1.803000e+03   1803.000000   1803.000000   1803.000000   1803.000000
# mean   7.217435e+05     78.283128   2008.357737     74.790372   5408.078203
# std    3.495766e+05      9.752816      1.537590     10.844857   4844.573926
# min    1.712600e+04     44.000000   2001.000000     40.000000      2.000000
# 25%    4.076870e+05     72.000000   2008.000000     66.800000    533.000000
# 50%    7.311070e+05     79.600000   2009.000000     74.600000   4450.000000
# 75%    1.037145e+06     86.000000   2009.000000     82.800000   9020.000000
# max    1.297877e+06     97.000000   2012.000000     98.200000  18409.000000
#
#        CollegeTier   collegeGPA  CollegeCityID  CollegeCityTier  \
# count  1803.000000  1803.000000    1803.000000      1803.000000
# mean      1.929007    71.566312    5408.078203         0.305047
# std       0.256884     7.947833    4844.573926         0.460555
# ...

# %%
# <fill_this>

validation_df.head()
# Out:
#           ID Gender         DOB  10percentage  12graduation  12percentage  \
# 0     230553      m  1992-05-01         66.66          2005          80.4
# 1    1038837      m  1990-09-21         73.00          2008          76.0
# 2     781196      m  1991-02-09         78.40          2009          58.4
# 3     661812      f  1991-09-23         71.00          2009          68.0
# 4     657409      m  1992-01-08         76.50          2009          84.0
# ..       ...    ...         ...           ...           ...           ...
# 594   309190      m  1986-02-06         48.00          2004          63.6
# 595    35122      m  1991-02-14         62.00          2006          71.0
# 596   568835      m  1991-01-07         77.20          2008          79.8
# 597   295545      m  1987-11-17         73.73          2005          72.5
# 598   326612      m  1990-09-15         87.60          2008          86.4
#
#      CollegeID  CollegeTier       Degree  \
# ...

# %% [markdown]
# > Insights:

# %%
training_df.shape
# Out:
# (1803, 58)

# %%
validation_df.describe()
# Out:
#                  ID  10percentage  12graduation  12percentage     CollegeID  \
# count  5.990000e+02    599.000000    599.000000    599.000000    599.000000
# mean   6.915486e+05     74.281452   2007.896494     71.254808   5596.098497
# std    3.776581e+05     10.236754      1.665900     11.195747   4903.705079
# min    2.122900e+04     43.000000   2001.000000     43.000000     13.000000
# 25%    3.305635e+05     67.000000   2007.000000     63.000000    993.000000
# 50%    6.609380e+05     75.000000   2008.000000     70.000000   4439.000000
# 75%    1.062176e+06     82.000000   2009.000000     79.800000   9459.000000
# max    1.297763e+06     97.120000   2011.000000     97.500000  17782.000000
#
#        CollegeTier  collegeGPA  CollegeCityID  CollegeCityTier  \
# count   599.000000  599.000000     599.000000       599.000000
# mean      1.969950   70.090668    5596.098497         0.288815
# std       0.170868    8.202505    4903.705079         0.453590
# ...

# %%
# <fill_this>

validation_df
# Out:
#           ID Gender         DOB  10percentage  12graduation  12percentage  \
# 0     230553      m  1992-05-01         66.66          2005          80.4
# 1    1038837      m  1990-09-21         73.00          2008          76.0
# 2     781196      m  1991-02-09         78.40          2009          58.4
# 3     661812      f  1991-09-23         71.00          2009          68.0
# 4     657409      m  1992-01-08         76.50          2009          84.0
# ..       ...    ...         ...           ...           ...           ...
# 594   309190      m  1986-02-06         48.00          2004          63.6
# 595    35122      m  1991-02-14         62.00          2006          71.0
# 596   568835      m  1991-01-07         77.20          2008          79.8
# 597   295545      m  1987-11-17         73.73          2005          72.5
# 598   326612      m  1990-09-15         87.60          2008          86.4
#
#      CollegeID  CollegeTier       Degree  \
# ...

# %% [markdown]
# > Insights: <fill_this>

# %%
# <fill_this>

testing_df
# Out:
#           ID Gender         DOB  10percentage  12graduation  12percentage  \
# 0     669692      m  1992-05-04         73.00          2009         71.00
# 1      87319      m  1986-10-27         56.40          2006         72.00
# 2     962441      m  1992-08-10         88.67          2009         87.69
# 3     110863      m  1988-08-04         85.60          2006         90.60
# 4    1083018      m  1992-08-25         91.00          2010         91.20
# ..       ...    ...         ...           ...           ...           ...
# 591   910069      m  1993-05-07         89.00          2010         82.20
# 592   262440      m  1988-02-07         78.00          2006         83.00
# 593   337533      m  1990-09-18         90.30          2008         96.25
# 594   896469      m  1992-05-29         86.88          2010         80.83
# 595   715228      m  1991-08-06         82.80          2008         73.11
#
#      CollegeID  CollegeTier       Degree  \
# ...

# %% [markdown]
# > Insights: <fill_this>

# %%
# <fill_this>

# %% [markdown]
# > Insights: <fill_this>

# %%
# <fill_this>

# %% [markdown]
# > Insights: <fill_this>

# %% [markdown]
# > Considerations: <fill_this>

# %% [markdown]
# > Issues found: <fill_this>

# %% [markdown]
# <hr>

# %% [markdown]
# ### C.3 Explore Target variable

# %%
# Set the name of the target column
# <fill_this>

target_name = ''

# %%
# <fill_this>

training_df[target_name]

# %% [markdown]
# > Insights: <fill_this>

# %%
# <fill_this>

# %% [markdown]
# > Insights: <fill_this>

# %%
# <fill_this>

# %% [markdown]
# > Insights: <fill_this>

# %% [markdown]
# > Considerations: <fill_this>

# %% [markdown]
# > Issues found: <fill_this>

# %% [markdown]
# <hr>

# %% [markdown]
# ### C.4 Explore Variables of Interest

# %% [markdown]
# <hr>

# %% [markdown]
# #### C.4.a Feature "<put_name_here>"

# %%
# <fill_this>

training_df['']

# %% [markdown]
# > Insights: <fill_this>

# %%
# <fill_this>

# %% [markdown]
# > Insights: <fill_this>

# %%
# <fill_this>

# %% [markdown]
# > Insights: <fill_this>

# %% [markdown]
# > Considerations: <fill_this>

# %% [markdown]
# > Issues found: <fill_this>

# %% [markdown]
# #### C.4.b Feature "<put_name_here>"

# %%
# <fill_this>

training_df['']

# %% [markdown]
# > Insights: <fill_this>

# %%
# <fill_this>

# %% [markdown]
# > Insights: <fill_this>

# %%
# <fill_this>

# %% [markdown]
# > Insights: <fill_this>

# %% [markdown]
# > Considerations: <fill_this>

# %% [markdown]
# > Issues found: <fill_this>

# %% [markdown]
# <hr>

# %% [markdown]
# ## D. Feature Selection

# %%
feature_selection_executive_summary = '<fill_this>'

# %% [markdown]
# ### D.1 Approach 1

# %% [markdown]
# > Rationale: <fill_this>

# %%
# <fill_this>

# %% [markdown]
# > Results: <fill_this>

# %% [markdown]
# ### D.2 Approach 2

# %% [markdown]
# > Rationale: <fill_this>

# %%
# <fill_this>

# %% [markdown]
# > Results: <fill_this>

# %% [markdown]
# ### D.3 Final Selection of Features

# %%
# <fill_this>

features_list = []

# %% [markdown]
# <hr>

# %% [markdown]
# ## E. Data Cleaning

# %%
data_cleaning_executive_summary = '<fill_this>'

# %% [markdown]
# ### E.1 Copy Datasets

# %%
# Create copy of datasets
# Do not change this code

training_df_clean = training_df[features_list].copy()
validation_df_clean = validation_df[features_list].copy()
testing_df_clean = testing_df[features_list].copy()

# %% [markdown]
# <hr>

# %% [markdown]
# ### E.2 Fixing "<put_issue_here>"

# %% [markdown]
# > Rationale: <fill_this>

# %%
# <fill_this>

# %% [markdown]
# > Results: <fill_this>

# %% [markdown]
# <hr>

# %% [markdown]
# ### E.3 Fixing "<put_issue_here>"

# %% [markdown]
# > Rationale: <fill_this>

# %%
# <fill_this>

# %% [markdown]
# > Results: <fill_this>

# %% [markdown]
# <hr>

# %% [markdown]
# ### E.4 Fixing "<put_issue_here>"

# %% [markdown]
# > Rationale:  <fill_this>

# %%
# <fill_this>

# %% [markdown]
# > Results: <fill_this>

# %% [markdown]
# <hr>

# %% [markdown]
# ## F. Feature Engineering

# %%
feature_engineering_executive_summary = '<fill_this>'

# %% [markdown]
# <hr>

# %% [markdown]
# ### F.1 Copy Datasets

# %%
# Create copy of datasets
# Do not change this code

training_df_eng = training_df_clean.copy()
validation_df_eng = validation_df_clean.copy()
testing_df_eng = testing_df_clean.copy()

# %% [markdown]
# <hr>

# %% [markdown]
# ### F.2 New Feature "<put_name_here>"

# %% [markdown]
# > Rationale: <fill_this>

# %%
# <fill_this>

# %% [markdown]
# > Results: <fill_this>

# %% [markdown]
# <hr>

# %% [markdown]
# ### F.3 New Feature "<put_name_here>"

# %% [markdown]
# > Rationale: <fill_this>

# %%
# <fill_this>

# %% [markdown]
# > Results: <fill_this>

# %% [markdown]
# <hr>

# %% [markdown]
# ### F.4 New Feature "<put_name_here>"

# %% [markdown]
# > Rationale: <fill_this>

# %%
# <fill_this>

# %% [markdown]
# > Results: <fill_this>

# %% [markdown]
# <hr>

# %% [markdown]
# ## G. Data Preparation for Modeling

# %%
modeling_preparation_executive_summary = '<fill_this>'

# %% [markdown]
# <hr>

# %% [markdown]
# ### G.1 Split Datasets

# %%
# Create copy of datasets
# Do not change this code

X_train = training_df_eng.copy()
X_val = validation_df.copy()
X_test = testing_df.copy()

y_train = X_train.pop(target_name)
y_val = X_val.pop(target_name)
y_test = X_test.pop(target_name)

# %% [markdown]
# <hr>

# %% [markdown]
# ### G.2 Data Transformation <put_name_here>

# %% [markdown]
# > Rationale: <fill_this>

# %%
# <fill_this>

# %% [markdown]
# > Results: <fill_this>

# %% [markdown]
# <hr>

# %% [markdown]
# ### G.3 Data Transformation <put_name_here>

# %% [markdown]
# > Rationale: <fill_this>

# %%
# <fill_this>

# %% [markdown]
# > Results: <fill_this>

# %% [markdown]
# <hr>

# %% [markdown]
# ### G.4 Data Transformation <put_name_here>

# %% [markdown]
# > Rationale: <fill_this>

# %%
# <fill_this>

# %% [markdown]
# > Results: <fill_this>

# %% [markdown]
# <hr>

# %% [markdown]
# ## H. Save Datasets

# %%
# Save training set
# Do not change this code

X_train.to_csv('X_train.csv', index=False)
y_train.to_csv('y_train.csv', index=False)

# %%
# Save validation set
# Do not change this code

X_val.to_csv('X_val.csv', index=False)
y_val.to_csv('y_val.csv', index=False)

# %%
# Save testing set
# Do not change this code

X_test.to_csv('X_test.csv', index=False)
y_test.to_csv('y_test.csv', index=False)

# %% [markdown]
# ## I. Assess Baseline Model

# %%
baseline_model_executive_summary = '<fill_this>'

# %% [markdown]
# <hr>

# %% [markdown]
# ### I.1 Simulate Predictions with Baseline Model

# %% [markdown]
# > Rationale: <fill_this>

# %%
# Define central value for baseline model
# <fill_this>

y_central =

# %%
# <fill_this>

training_preds =

# %% [markdown]
# <hr>

# %% [markdown]
# ### I.2 Selection of Performance Metrics

# %% [markdown]
# > Rationale: <fill_this>

# %%
# <fill_this>

from sklearn.metrics import

# %% [markdown]
# <hr>

# %% [markdown]
# ### I.2 Baseline Model Performance

# %%
# <fill_this>

# %% [markdown]
# > Results: <fill_this>

# %% [markdown]
# <hr>

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=737d9b25-9447-484d-8bc7-c0ef42078df9' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
